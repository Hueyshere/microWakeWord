# %% [markdown]
# # Training a microWakeWord Model
#
# This notebook steps you through training a basic microWakeWord model. It is intended as a **starting point** for advanced users. You should use Python 3.10.
#
# **The model generated will most likely not be usable for everyday use; it may be difficult to trigger or falsely activates too frequently. You will most likely have to experiment with many different settings to obtain a decent model!**
#
# In the comment at the start of certain blocks, I note some specific settings to consider modifying.
#
# This runs on Google Colab, but is extremely slow compared to training on a local GPU. If you must use Colab, be sure to Change the runtime type to a GPU. Even then, it still slow!
#
# At the end of this notebook, you will be able to download a tflite file. To use this in ESPHome, you need to write a model manifest JSON file. See the [ESPHome documentation](https://esphome.io/components/micro_wake_word) for the details and the [model repo](https://github.com/esphome/micro-wake-word-models/tree/main/models/v2) for examples.

# %%
# Installs microWakeWord. Be sure to restart the session after this is finished.
import platform

if platform.system() == "Darwin":
    # `pymicro-features` is installed from a fork to support building on macOS
    # !pip install 'git+https://github.com/puddly/pymicro-features@puddly/minimum-cpp-version'

# `audio-metadata` is installed from a fork to unpin `attrs` from a version that breaks Jupyter
# !pip install 'git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'

# !git clone https://github.com/kahrendt/microWakeWord
# !pip install -e ./microWakeWord
# Out:
# Collecting git+https://github.com/puddly/pymicro-features@puddly/minimum-cpp-version
#   Cloning https://github.com/puddly/pymicro-features (to revision puddly/minimum-cpp-version) to /private/var/folders/wy/86qmzn49731_jwtmfw6_5lg80000gn/T/pip-req-build-qezzsprf
#   Running command git clone --filter=blob:none --quiet https://github.com/puddly/pymicro-features /private/var/folders/wy/86qmzn49731_jwtmfw6_5lg80000gn/T/pip-req-build-qezzsprf
#   Running command git checkout -b puddly/minimum-cpp-version --track origin/puddly/minimum-cpp-version
#   切换到一个新分支 'puddly/minimum-cpp-version'
#   分支 'puddly/minimum-cpp-version' 设置为跟踪 'origin/puddly/minimum-cpp-version'。
#   Resolved https://github.com/puddly/pymicro-features to commit e1d3f88183e12bb8af2df9e399ea157af7393762
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting git+https://github.com/whatsnowplaying/audio-metadata@d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Cloning https://github.com/whatsnowplaying/audio-metadata (to revision d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f) to /private/var/folders/wy/86qmzn49731_jwtmfw6_5lg80000gn/T/pip-req-build-eeaxq27l
#   Running command git clone --filter=blob:none --quiet https://github.com/whatsnowplaying/audio-metadata /private/var/folders/wy/86qmzn49731_jwtmfw6_5lg80000gn/T/pip-req-build-eeaxq27l
#   Running command git rev-parse -q --verify 'sha^d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f'
#   Running command git fetch -q https://github.com/whatsnowplaying/audio-metadata d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Running command git checkout -q d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Resolved https://github.com/whatsnowplaying/audio-metadata to commit d4ebb238e6a401bb1a5aaaac60c9e2b3cb30929f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=18.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio-metadata==0.12.0) (25.3.0)
# Requirement already satisfied: bidict==0.* in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio-metadata==0.12.0) (0.23.1)
# Requirement already satisfied: bitstruct<9.0,>=6.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio-metadata==0.12.0) (8.21.0)
# Requirement already satisfied: more-itertools<9.0,>=4.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio-metadata==0.12.0) (8.14.0)
# Requirement already satisfied: pprintpp==0.* in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio-metadata==0.12.0) (0.4.0)
# Requirement already satisfied: wrapt<2.0,>=1.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio-metadata==0.12.0) (1.17.2)
# 致命错误：目标路径 'microWakeWord' 已经存在，并且不是一个空目录。
# Obtaining file:///Users/huanyu/Desktop/microWakeWord/notebooks/microWakeWord
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: audiomentations in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.41.0)
# Requirement already satisfied: audio_metadata in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.12.0)
# Requirement already satisfied: datasets in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (3.6.0)
# Requirement already satisfied: mmap_ninja in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (0.7.4)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (2.1.3)
# Requirement already satisfied: pymicro-features in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (1.0.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (6.0.2)
# Requirement already satisfied: tensorflow>=2.16 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (2.19.0)
# Requirement already satisfied: webrtcvad in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from microwakeword==0.1.0) (2.0.10)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.32.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (78.1.1)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (1.73.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.5.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorflow>=2.16->microwakeword==0.1.0) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow>=2.16->microwakeword==0.1.0) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0) (3.8.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.16->microwakeword==0.1.0) (0.45.1)
# Requirement already satisfied: rich in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (14.0.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow>=2.16->microwakeword==0.1.0) (3.0.2)
# Requirement already satisfied: attrs>=18.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (25.3.0)
# Requirement already satisfied: bidict==0.* in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (0.23.1)
# Requirement already satisfied: bitstruct<9.0,>=6.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (8.21.0)
# Requirement already satisfied: more-itertools<9.0,>=4.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (8.14.0)
# Requirement already satisfied: pprintpp==0.* in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audio_metadata->microwakeword==0.1.0) (0.4.0)
# Requirement already satisfied: numpy-minmax<1,>=0.3.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.4.0)
# Requirement already satisfied: numpy-rms<1,>=0.4.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.5.0)
# Requirement already satisfied: librosa!=0.10.0,<0.11.0,>=0.8.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.10.2.post1)
# Requirement already satisfied: python-stretch<1,>=0.3.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.3.1)
# Requirement already satisfied: scipy<2,>=1.4 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (1.15.3)
# Requirement already satisfied: soxr<1.0.0,>=0.3.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from audiomentations->microwakeword==0.1.0) (0.5.0.post1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.7.0)
# Requirement already satisfied: joblib>=0.14 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (5.2.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.61.2)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.8.2)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (1.1.1)
# Requirement already satisfied: cffi>=1.0.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from cffi>=1.0.0->numpy-minmax<1,>=0.3.0->audiomentations->microwakeword==0.1.0) (2.22)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from numba>=0.51.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from pooch>=1.1->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (4.3.8)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa!=0.10.0,<0.11.0,>=0.8.0->audiomentations->microwakeword==0.1.0) (3.6.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (2.3.0)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (4.67.1)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from datasets->microwakeword==0.1.0) (0.33.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (3.12.13)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (5.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->microwakeword==0.1.0) (1.20.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets->microwakeword==0.1.0) (1.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from pandas->datasets->microwakeword==0.1.0) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.16->microwakeword==0.1.0) (0.1.2)
# Building wheels for collected packages: microwakeword
#   Building editable for microwakeword (pyproject.toml) ... done
#   Created wheel for microwakeword: filename=microwakeword-0.1.0-0.editable-py3-none-any.whl size=9919 sha256=7620cf5e99d03b0a2305d6708ce6f4c758c7ac525a8d2cbae68ad46b8f3e6ccd
#   Stored in directory: /private/var/folders/wy/86qmzn49731_jwtmfw6_5lg80000gn/T/pip-ephem-wheel-cache-rg5n2j7z/wheels/5c/b2/09/f9efae557e6e8d15ed2a4645f9ffd0b1b2af04daa0144208f8
# Successfully built microwakeword
# Installing collected packages: microwakeword
#   Attempting uninstall: microwakeword
#     Found existing installation: microwakeword 0.1.0
#     Uninstalling microwakeword-0.1.0:
#       Successfully uninstalled microwakeword-0.1.0
# Successfully installed microwakeword-0.1.0

# %%
# Generates 1 sample of the target word for manual verification.

target_word = 'hey_ploude'  # Phonetic spellings may produce better samples

import os
import sys
import platform 

from IPython.display import Audio

if not os.path.exists("./piper-sample-generator"):
    if platform.system() == "Darwin":
        # !git clone -b mps-support https://github.com/kahrendt/piper-sample-generator
    else:
        # !git clone https://github.com/rhasspy/piper-sample-generator

    # !wget -O piper-sample-generator/models/en_US-libritts_r-medium.pt 'https://github.com/rhasspy/piper-sample-generator/releases/download/v2.0.0/en_US-libritts_r-medium.pt'

    # Install system dependencies
    # !pip install torch torchaudio piper-phonemize-cross==1.2.1

    if "piper-sample-generator/" not in sys.path:
        sys.path.append("piper-sample-generator/")

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1 \
--batch-size 1 \
--output-dir generated_samples

Audio("generated_samples/0.wav", autoplay=True)
# Out:
# DEBUG:__main__:Loading /Users/huanyu/Desktop/microWakeWord/notebooks/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:MPS available, using GPU
# /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages/torch/nn/functional.py:5209: UserWarning: MPS: The constant padding of more than 3 dimensions is not currently supported natively. It uses View Ops default implementation to run. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Pad.mm:465.)
#   return torch._C._nn.pad(input, pad, mode, value)
# DEBUG:__main__:Batch 1/1 complete
# INFO:__main__:Done
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Generates a larger amount of wake word samples.
# Start here when trying to improve your model.
# See https://github.com/rhasspy/piper-sample-generator for the full set of
# parameters. In particular, experiment with noise-scales and noise-scale-ws,
# generating negative samples similar to the wake word, and generating many more
# wake word samples, possibly with different phonetic pronunciations.

# !python3 piper-sample-generator/generate_samples.py "{target_word}" \
--max-samples 1000 \
--batch-size 100 \
--output-dir generated_samples
# Out:
# DEBUG:__main__:Loading /Users/huanyu/Desktop/microWakeWord/notebooks/piper-sample-generator/models/en_US-libritts_r-medium.pt
# INFO:__main__:Successfully loaded the model
# DEBUG:__main__:MPS available, using GPU
# /opt/anaconda3/envs/microwakeword-env/lib/python3.10/site-packages/torch/nn/functional.py:5209: UserWarning: MPS: The constant padding of more than 3 dimensions is not currently supported natively. It uses View Ops default implementation to run. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Pad.mm:465.)
#   return torch._C._nn.pad(input, pad, mode, value)
# DEBUG:__main__:Batch 1/10 complete
# DEBUG:__main__:Batch 2/10 complete
# DEBUG:__main__:Batch 3/10 complete
# DEBUG:__main__:Batch 4/10 complete
# DEBUG:__main__:Batch 5/10 complete
# DEBUG:__main__:Batch 6/10 complete
# DEBUG:__main__:Batch 7/10 complete
# DEBUG:__main__:Batch 8/10 complete
# DEBUG:__main__:Batch 9/10 complete
# DEBUG:__main__:Batch 10/10 complete
# INFO:__main__:Done

# %%
# Downloads audio data for augmentation. This can be slow!
# Borrowed from openWakeWord's automatic_model_training.ipynb, accessed March 4, 2024
#
# **Important note!** The data downloaded here has a mixture of difference
# licenses and usage restrictions. As such, any custom models trained with this
# data should be considered as appropriate for **non-commercial** personal use only.


import datasets
import scipy
import os

import numpy as np

from pathlib import Path
from tqdm import tqdm

## Download MIR RIR data

output_dir = "./mit_rirs"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    rir_dataset = datasets.load_dataset("davidscripka/MIT_environmental_impulse_responses", split="train", streaming=True)
    # Save clips to 16-bit PCM wav files
    for row in tqdm(rir_dataset):
        name = row['audio']['path'].split('/')[-1]
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

## Download noise and background audio

# Audioset Dataset (https://research.google.com/audioset/dataset/index.html)
# Download one part of the audioset .tar files, extract, and convert to 16khz
# For full-scale training, it's recommended to download the entire dataset from
# https://huggingface.co/datasets/agkphysics/AudioSet, and
# even potentially combine it with other background noise datasets (e.g., FSD50k, Freesound, etc.)

if not os.path.exists("audioset"):
    os.mkdir("audioset")

    fname = "bal_train09.tar"
    out_dir = f"audioset/{fname}"
    link = "https://huggingface.co/datasets/agkphysics/AudioSet/resolve/main/data/" + fname
    # !wget -O {out_dir} {link}
    # !cd audioset && tar -xf bal_train09.tar

    output_dir = "./audioset_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    audioset_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("audioset/audio").glob("**/*.flac")]})
    audioset_dataset = audioset_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(audioset_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".flac", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# Free Music Archive dataset
# https://github.com/mdeff/fma
# (Third-party mchl914 extra small set)

output_dir = "./fma"
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    fname = "fma_xs.zip"
    link = "https://huggingface.co/datasets/mchl914/fma_xsmall/resolve/main/" + fname
    out_dir = f"fma/{fname}"
    # !wget -O {out_dir} {link}
    # !cd {output_dir} && unzip -q {fname}

    output_dir = "./fma_16k"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)

    # Save clips to 16-bit PCM wav files
    fma_dataset = datasets.Dataset.from_dict({"audio": [str(i) for i in Path("fma/fma_small").glob("**/*.mp3")]})
    fma_dataset = fma_dataset.cast_column("audio", datasets.Audio(sampling_rate=16000))
    for row in tqdm(fma_dataset):
        name = row['audio']['path'].split('/')[-1].replace(".mp3", ".wav")
        scipy.io.wavfile.write(os.path.join(output_dir, name), 16000, (row['audio']['array']*32767).astype(np.int16))

# %%
# Sets up the augmentations.
# To improve your model, experiment with these settings and use more sources of background clips.

from microwakeword.audio.augmentation import Augmentation
from microwakeword.audio.clips import Clips
from microwakeword.audio.spectrograms import SpectrogramGeneration

clips = Clips(input_directory='generated_samples',
              file_pattern='*.wav',
              max_clip_duration_s=None,
              remove_silence=False,
              random_split_seed=10,
              split_count=0.1,
              )
augmenter = Augmentation(augmentation_duration_s=3.2,
                         augmentation_probabilities = {
                                "SevenBandParametricEQ": 0.1,
                                "TanhDistortion": 0.1,
                                "PitchShift": 0.1,
                                "BandStopFilter": 0.1,
                                "AddColorNoise": 0.1,
                                "AddBackgroundNoise": 0.75,
                                "Gain": 1.0,
                                "RIR": 0.5,
                            },
                         impulse_paths = [],# ['mit_rirs'], # ！！！这里手动修改过
                         background_paths = ['fma_16k', 'audioset_16k'],
                         background_min_snr_db = -5,
                         background_max_snr_db = 10,
                         min_jitter_s = 0.195,
                         max_jitter_s = 0.205,
                         )

# %%
# Augment a random clip and play it back to verify it works well

from IPython.display import Audio
from microwakeword.audio.audio_utils import save_clip

random_clip = clips.get_random_clip()
augmented_clip = augmenter.augment_clip(random_clip)
save_clip(augmented_clip, 'augmented_clip.wav')

Audio("augmented_clip.wav", autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Augment samples and save the training, validation, and testing sets.
# Validating and testing samples generated the same way can make the model
# benchmark better than it performs in real-word use. Use real samples or TTS
# samples generated with a different TTS engine to potentially get more accurate
# benchmarks.

import os
from mmap_ninja.ragged import RaggedMmap

output_dir = 'generated_augmented_features'

if not os.path.exists(output_dir):
    os.mkdir(output_dir)

splits = ["training", "validation", "testing"]
for split in splits:
  out_dir = os.path.join(output_dir, split)
  if not os.path.exists(out_dir):
      os.mkdir(out_dir)


  split_name = "train"
  repetition = 2

  spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=10,    # Uses the same spectrogram repeatedly, just shifted over by one frame. This simulates the streaming inferences while training/validating in nonstreaming mode.
                                     step_ms=10,
                                     )
  if split == "validation":
    split_name = "validation"
    repetition = 1
  elif split == "testing":
    split_name = "test"
    repetition = 1
    spectrograms = SpectrogramGeneration(clips=clips,
                                     augmenter=augmenter,
                                     slide_frames=1,    # The testing set uses the streaming version of the model, so no artificial repetition is necessary
                                     step_ms=10,
                                     )

  RaggedMmap.from_generator(
      out_dir=os.path.join(out_dir, 'wakeword_mmap'),
      sample_generator=spectrograms.spectrogram_generator(split=split_name, repeat=repetition),
      batch_size=100,
      verbose=True,
  )
# Out:
# 16000it [00:20, 789.55it/s]
# 1000it [00:01, 827.57it/s]
# 100it [00:00, 144.65it/s]

# %%
# Downloads pre-generated spectrogram features (made for microWakeWord in
# particular) for various negative datasets. This can be slow!

output_dir = './negative_datasets'
if not os.path.exists(output_dir):
    os.mkdir(output_dir)
    link_root = "https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/"
    filenames = ['dinner_party.zip', 'dinner_party_eval.zip', 'no_speech.zip', 'speech.zip']
    for fname in filenames:
        link = link_root + fname

        zip_path = f"negative_datasets/{fname}"
        # !wget -O {zip_path} {link}
        # !unzip -q {zip_path} -d {output_dir}
# Out:
# --2025-06-19 14:00:27--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/dinner_party.zip
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 302 Found
# 位置：https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/18a0885d595ced7faa73736a8680206f5ba6e80113ca3e6ce43130e510aac18f?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party.zip%3B+filename%3D%22dinner_party.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316428&Policy=...&Signature=o2gS7jp5iSz-uj3gjiLpkCGMDoPsPiTfZbNoDtLvg-ra-hy-NdGzzDyg8STs1FSYbUO10BaLFB6cliHXz-ixI37hGm7FWLQaqcyzpUjvSR7ahB1LB8-U2CEs0NgXooxwTl%7ED-qfSy2URDO%7ESUsvbbKYYxy0%7ELnm2hHhltd-ANWx6AXyYqoMo-z45Uc8n7CFAJMIpR99a9Z1jEBiV1OYc90yQ7xqkrHL5uXqWPFYq1z0x-u%7EcePTW00IuQ7ASDjRyHadcOlu%7ExNxKjOPvj2rxiqJ3Jtzz8iw4W-z8nWoFkSILr%7E%7EWClg%7EQkM9OJBJJF-JJqbvYn9tm%7EuwYZlWAAcbZw__&Key-Pair-Id=K24J24Z295AEI9 [跟随至新的 URL]
# --2025-06-19 14:00:29--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/18a0885d595ced7faa73736a8680206f5ba6e80113ca3e6ce43130e510aac18f?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party.zip%3B+filename%3D%22dinner_party.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316428&Policy=...&Signature=o2gS7jp5iSz-uj3gjiLpkCGMDoPsPiTfZbNoDtLvg-ra-hy-NdGzzDyg8STs1FSYbUO10BaLFB6cliHXz-ixI37hGm7FWLQaqcyzpUjvSR7ahB1LB8-U2CEs0NgXooxwTl%7ED-qfSy2URDO%7ESUsvbbKYYxy0%7ELnm2hHhltd-ANWx6AXyYqoMo-z45Uc8n7CFAJMIpR99a9Z1jEBiV1OYc90yQ7xqkrHL5uXqWPFYq1z0x-u%7EcePTW00IuQ7ASDjRyHadcOlu%7ExNxKjOPvj2rxiqJ3Jtzz8iw4W-z8nWoFkSILr%7E%7EWClg%7EQkM9OJBJJF-JJqbvYn9tm%7EuwYZlWAAcbZw__&Key-Pair-Id=K24J24Z295AEI9
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度：444310142 (424M) [application/zip]
# 正在保存至: “negative_datasets/dinner_party.zip”
#
# negative_datasets/d 100%[===================>] 423.73M  13.8MB/s  用时 34s
#
# 2025-06-19 14:01:05 (12.3 MB/s) - 已保存 “negative_datasets/dinner_party.zip” [444310142/444310142])
#
# --2025-06-19 14:01:18--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/dinner_party_eval.zip
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 302 Found
# 位置：https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/e08e23a5e654dd4415a1c41a4b6cd02d1f983c821512367ad937bac1aeed8299?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party_eval.zip%3B+filename%3D%22dinner_party_eval.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316479&Policy=...&Signature=Zrlg0MKpRHHggGSc-yFODGf6c5g9Pw9WKlFUXK1FEbTSrsciV5ebPfC3z5GvG61WcbAGsqlnyZUPSLPnRtfcxKKI3EwUF7gWAkQ2N-sxmmNYtXx6tjhwLu8dvyzlnqePmks-rH8M2BA3HyKQCfyjqMsuQY3tlKqqvKxPmb0seTHbuMZZWel4CNLnBHHd9z3xDRB47dUtsF4weKfeC9T%7EK0MwIw4OTK6lmm5P0CsNeBef7%7Ev6gQa8VTlAmYtoit%7EQohsK4IYZnm%7ETmt8bfPHgeRRPxdiBIegSU1oC8Ap7cOgCycTRHMhJHVB9Ot3YjljNblJAR8JdcaJ-5nZ6dA4pQA__&Key-Pair-Id=K24J24Z295AEI9 [跟随至新的 URL]
# --2025-06-19 14:01:20--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/e08e23a5e654dd4415a1c41a4b6cd02d1f983c821512367ad937bac1aeed8299?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27dinner_party_eval.zip%3B+filename%3D%22dinner_party_eval.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316479&Policy=...&Signature=Zrlg0MKpRHHggGSc-yFODGf6c5g9Pw9WKlFUXK1FEbTSrsciV5ebPfC3z5GvG61WcbAGsqlnyZUPSLPnRtfcxKKI3EwUF7gWAkQ2N-sxmmNYtXx6tjhwLu8dvyzlnqePmks-rH8M2BA3HyKQCfyjqMsuQY3tlKqqvKxPmb0seTHbuMZZWel4CNLnBHHd9z3xDRB47dUtsF4weKfeC9T%7EK0MwIw4OTK6lmm5P0CsNeBef7%7Ev6gQa8VTlAmYtoit%7EQohsK4IYZnm%7ETmt8bfPHgeRRPxdiBIegSU1oC8Ap7cOgCycTRHMhJHVB9Ot3YjljNblJAR8JdcaJ-5nZ6dA4pQA__&Key-Pair-Id=K24J24Z295AEI9
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度：82329019 (79M) [application/zip]
# 正在保存至: “negative_datasets/dinner_party_eval.zip”
#
# negative_datasets/d 100%[===================>]  78.51M  14.1MB/s  用时 7.0s
#
# 2025-06-19 14:01:28 (11.2 MB/s) - 已保存 “negative_datasets/dinner_party_eval.zip” [82329019/82329019])
#
# --2025-06-19 14:01:31--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/no_speech.zip
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 302 Found
# 位置：https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/722dbcc967275c64c9581ecb85729549830a9094ce605ee22b2ddab9dbabf3c8?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27no_speech.zip%3B+filename%3D%22no_speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316493&Policy=...&Signature=inmdea8BRn0d6ejEoYkct06oH2Ul2ejGMakVuIhrgiMTmWup2B1nzkJBXMxOpcSsMGwRNT1gGPrn%7Eqp12V9YYqe5%7E5qsROxUzmpUqzfa0eMod9XyW60slCfPpXMb1SN%7EJcOJcRkr6E8wHE9xIom1uwaZ%7E7LJBwubuPLTIHdIdbpYwioqR44g%7Eyfzp8dBnyajC5Xq%7E4oi%7Eilebns0FxgXgaEp%7E-IHIzVCvghxvU5YjGXqrlP5Sa00A9gxMbeUsxqjouXbo87P-d1WtVdbKXlhCBqkTrwV3uvTOI3ltR3v%7EeDyNPY8WgPAqAuactQ3Pm8HpSHNSglNZtAk6%7EV7rZceyA__&Key-Pair-Id=K24J24Z295AEI9 [跟随至新的 URL]
# --2025-06-19 14:01:33--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/722dbcc967275c64c9581ecb85729549830a9094ce605ee22b2ddab9dbabf3c8?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27no_speech.zip%3B+filename%3D%22no_speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316493&Policy=...&Signature=inmdea8BRn0d6ejEoYkct06oH2Ul2ejGMakVuIhrgiMTmWup2B1nzkJBXMxOpcSsMGwRNT1gGPrn%7Eqp12V9YYqe5%7E5qsROxUzmpUqzfa0eMod9XyW60slCfPpXMb1SN%7EJcOJcRkr6E8wHE9xIom1uwaZ%7E7LJBwubuPLTIHdIdbpYwioqR44g%7Eyfzp8dBnyajC5Xq%7E4oi%7Eilebns0FxgXgaEp%7E-IHIzVCvghxvU5YjGXqrlP5Sa00A9gxMbeUsxqjouXbo87P-d1WtVdbKXlhCBqkTrwV3uvTOI3ltR3v%7EeDyNPY8WgPAqAuactQ3Pm8HpSHNSglNZtAk6%7EV7rZceyA__&Key-Pair-Id=K24J24Z295AEI9
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度：2000317854 (1.9G) [application/zip]
# 正在保存至: “negative_datasets/no_speech.zip”
#
# negative_datasets/n 100%[===================>]   1.86G  12.1MB/s  用时 2m 38s
#
# 2025-06-19 14:04:13 (12.0 MB/s) - 已保存 “negative_datasets/no_speech.zip” [2000317854/2000317854])
#
# --2025-06-19 14:05:08--  https://huggingface.co/datasets/kahrendt/microwakeword/resolve/main/speech.zip
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 302 Found
# 位置：https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/68b6b811b347b8321169f9e75ea2b9be73245943b4470af9532ca288d9f1b3cc?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27speech.zip%3B+filename%3D%22speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316710&Policy=...&Signature=RKOwKml%7E4N9xIXrBQ3lUDpo5DXZcLIlKW%7E6iTYQ%7EtcTN1hW5LLudMKwI6H6CHPb6bDB1vH0ksBLzcmq%7EXBdWasvP10KQAItKdgOThafw%7EEPl09JHCo2RmMM7dVyd-ptRtG%7Ey6EVx37RE7LOChqBsx7wqc5TqdyCOnXf54WvWlH8osnYXg5hGJjNPV2-252GuI60lr6fBfsKfnSz2hUlmkyh6sJQWdRqNFhZVhg9SFa%7EH2-LCrRFV7QWgqtVN8cbh5FQ6e%7Euldjo6Tcp7Qet0yZn5YPVQXIPJPtjx7XZOLqcQAfnUtbUU9oV4WS6UcM36ujNUghHBDw41M43ZTxnzQg__&Key-Pair-Id=K24J24Z295AEI9 [跟随至新的 URL]
# --2025-06-19 14:05:10--  https://cdn-lfs-us-1.hf.co/repos/1e/47/1e471239a0f43987de7dbb41f4104451fd310e7e21a669f6bd46eabbcf977aff/68b6b811b347b8321169f9e75ea2b9be73245943b4470af9532ca288d9f1b3cc?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27speech.zip%3B+filename%3D%22speech.zip%22%3B&response-content-type=application%2Fzip&Expires=1750316710&Policy=...&Signature=RKOwKml%7E4N9xIXrBQ3lUDpo5DXZcLIlKW%7E6iTYQ%7EtcTN1hW5LLudMKwI6H6CHPb6bDB1vH0ksBLzcmq%7EXBdWasvP10KQAItKdgOThafw%7EEPl09JHCo2RmMM7dVyd-ptRtG%7Ey6EVx37RE7LOChqBsx7wqc5TqdyCOnXf54WvWlH8osnYXg5hGJjNPV2-252GuI60lr6fBfsKfnSz2hUlmkyh6sJQWdRqNFhZVhg9SFa%7EH2-LCrRFV7QWgqtVN8cbh5FQ6e%7Euldjo6Tcp7Qet0yZn5YPVQXIPJPtjx7XZOLqcQAfnUtbUU9oV4WS6UcM36ujNUghHBDw41M43ZTxnzQg__&Key-Pair-Id=K24J24Z295AEI9
# 正在连接 127.0.0.1:7890... 已连接。
# 已发出 Proxy 请求，正在等待回应... 200 OK
# 长度：3183001091 (3.0G) [application/zip]
# 正在保存至: “negative_datasets/speech.zip”
#
# negative_datasets/s 100%[===================>]   2.96G  11.1MB/s  用时 4m 57s
#
# 2025-06-19 14:10:09 (10.2 MB/s) - 已保存 “negative_datasets/speech.zip” [3183001091/3183001091])

# %%
# Save a yaml config that controls the training process
# These hyperparamters can make a huge different in model quality.
# Experiment with sampling and penalty weights and increasing the number of
# training steps.

import yaml
import os

config = {}

config["window_step_ms"] = 10

config["train_dir"] = (
    "trained_models/wakeword"
)


# Each feature_dir should have at least one of the following folders with this structure:
#  training/
#    ragged_mmap_folders_ending_in_mmap
#  testing/
#    ragged_mmap_folders_ending_in_mmap
#  testing_ambient/
#    ragged_mmap_folders_ending_in_mmap
#  validation/
#    ragged_mmap_folders_ending_in_mmap
#  validation_ambient/
#    ragged_mmap_folders_ending_in_mmap
#
#  sampling_weight: Weight for choosing a spectrogram from this set in the batch
#  penalty_weight: Penalizing weight for incorrect predictions from this set
#  truth: Boolean whether this set has positive samples or negative samples
#  truncation_strategy = If spectrograms in the set are longer than necessary for training, how are they truncated
#       - random: choose a random portion of the entire spectrogram - useful for long negative samples
#       - truncate_start: remove the start of the spectrogram
#       - truncate_end: remove the end of the spectrogram
#       - split: Split the longer spectrogram into separate spectrograms offset by 100 ms. Only for ambient sets

config["features"] = [
    {
        "features_dir": "generated_augmented_features",
        "sampling_weight": 2.0,
        "penalty_weight": 1.0,
        "truth": True,
        "truncation_strategy": "truncate_start",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/speech",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/dinner_party",
        "sampling_weight": 10.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    {
        "features_dir": "negative_datasets/no_speech",
        "sampling_weight": 5.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "random",
        "type": "mmap",
    },
    { # Only used for validation and testing
        "features_dir": "negative_datasets/dinner_party_eval",
        "sampling_weight": 0.0,
        "penalty_weight": 1.0,
        "truth": False,
        "truncation_strategy": "split",
        "type": "mmap",
    },
]

# Number of training steps in each iteration - various other settings are configured as lists that corresponds to different steps
config["training_steps"] = [10000]

# Penalizing weight for incorrect class predictions - lists that correspond to training steps
config["positive_class_weight"] = [1]
config["negative_class_weight"] = [20]

config["learning_rates"] = [
    0.001,
]  # Learning rates for Adam optimizer - list that corresponds to training steps
config["batch_size"] = 128

config["time_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["time_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps
config["freq_mask_max_size"] = [
    0
]  # SpecAugment - list that corresponds to training steps
config["freq_mask_count"] = [0]  # SpecAugment - list that corresponds to training steps

config["eval_step_interval"] = (
    500  # Test the validation sets after every this many steps
)
config["clip_duration_ms"] = (
    1500  # Maximum length of wake word that the streaming model will accept
)

# The best model weights are chosen first by minimizing the specified minimization metric below the specified target_minimization
# Once the target has been met, it chooses the maximum of the maximization metric. Set 'minimization_metric' to None to only maximize
# Available metrics:
#   - "loss" - cross entropy error on validation set
#   - "accuracy" - accuracy of validation set
#   - "recall" - recall of validation set
#   - "precision" - precision of validation set
#   - "false_positive_rate" - false positive rate of validation set
#   - "false_negative_rate" - false negative rate of validation set
#   - "ambient_false_positives" - count of false positives from the split validation_ambient set
#   - "ambient_false_positives_per_hour" - estimated number of false positives per hour on the split validation_ambient set
config["target_minimization"] = 0.9
config["minimization_metric"] = None  # Set to None to disable

config["maximization_metric"] = "average_viable_recall"

with open(os.path.join("training_parameters.yaml"), "w") as file:
    documents = yaml.dump(config, file)

# %%
# Trains a model. When finished, it will quantize and convert the model to a
# streaming version suitable for on-device detection.
# It will resume if stopped, but it will start over at the configured training
# steps in the yaml file.
# Change --train 0 to only convert and test the best-weighted model.
# On Google colab, it doesn't print the mini-batch results, so it may appear
# stuck for several minutes! Additionally, it is very slow compared to training
# on a local GPU.

# !python -m microwakeword.model_train_eval \
--training_config='training_parameters.yaml' \
--train 1 \
--restore_checkpoint 1 \
--test_tf_nonstreaming 0 \
--test_tflite_nonstreaming 0 \
--test_tflite_nonstreaming_quantized 0 \
--test_tflite_streaming 0 \
--test_tflite_streaming_quantized 1 \
--use_weights "best_weights" \
mixednet \
--pointwise_filters "64,64,64,64" \
--repeat_in_block  "1, 1, 1, 1" \
--mixconv_kernel_sizes '[5], [7,11], [9,15], [23]' \
--residual_connection "0,0,0,0" \
--first_conv_filters 32 \
--first_conv_kernel_size 5 \
--stride 3

# 结果在 "trained_models/wakeword/tflite_stream_state_internal_quant/stream_state_internal_quant.tflite" ～ 13min on M1 pro
# Out:
# INFO:absl:Loading and analyzing data sets.
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (128, 204, 40)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims         │ (128, 204, 1, 40) │          0 │ input_layer[0][0] │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream (Stream)     │ (128, 67, 1, 32)  │      6,400 │ expand_dims[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (128, 67, 1, 32)  │          0 │ stream[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_1 (Stream)   │ (128, 67, 1, 32)  │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (128, 63, 1, 32)  │        192 │ stream_1[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (128, 63, 1, 64)  │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (128, 63, 1, 64)  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (128, 63, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_2 (Stream)   │ (128, 63, 1, 64)  │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split       │ [(128, 63, 1,     │          0 │ stream_2[0][0]    │
# │ (ChannelSplit)      │ 32), (128, 63, 1, │            │                   │
# │                     │ 32)]              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep        │ (128, 63, 1, 32)  │          0 │ channel_split[0]… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_1      │ (128, 63, 1, 32)  │          0 │ channel_split[0]… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (128, 57, 1, 32)  │        256 │ strided_keep[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (128, 53, 1, 32)  │        384 │ strided_keep_1[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop        │ (128, 53, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_1      │ (128, 53, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (128, 53, 1, 64)  │          0 │ strided_drop[0][… │
# │ (Concatenate)       │                   │            │ strided_drop_1[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (128, 53, 1, 64)  │      4,096 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 53, 1, 64)  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (128, 53, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_3 (Stream)   │ (128, 53, 1, 64)  │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_1     │ [(128, 53, 1,     │          0 │ stream_3[0][0]    │
# │ (ChannelSplit)      │ 32), (128, 53, 1, │            │                   │
# │                     │ 32)]              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_2      │ (128, 53, 1, 32)  │          0 │ channel_split_1[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_3      │ (128, 53, 1, 32)  │          0 │ channel_split_1[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (128, 45, 1, 32)  │        320 │ strided_keep_2[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (128, 39, 1, 32)  │        512 │ strided_keep_3[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_2      │ (128, 39, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_3      │ (128, 39, 1, 32)  │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (128, 39, 1, 64)  │          0 │ strided_drop_2[0… │
# │ (Concatenate)       │                   │            │ strided_drop_3[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (128, 39, 1, 64)  │      4,096 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 39, 1, 64)  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (128, 39, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_4 (Stream)   │ (128, 39, 1, 64)  │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (128, 17, 1, 64)  │      1,536 │ stream_4[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (128, 17, 1, 64)  │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (128, 17, 1, 64)  │        256 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (128, 17, 1, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_5 (Stream)   │ (128, 17, 1, 64)  │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (128, 1088)       │          0 │ stream_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (128, 1)          │      1,089 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:None
# INFO:absl:Step #500: rate 0.001000, accuracy 98.81%, recall 90.14%, precision 93.33%, cross entropy 0.033815
# INFO:absl:Step 500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.70%, recall = 99.70%, precision = 100.00%, ambient false positives = 293, estimated false positives per hour = 30.29841, loss = 0.01157, auc = 0.99996, average viable recall = 0.864598977
# INFO:absl:Sharding callback duration: 44 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 86.45990%; no faph cutoff is 1.00
# INFO:absl:Step #1000: rate 0.001000, accuracy 99.84%, recall 98.61%, precision 99.18%, cross entropy 0.005414
# INFO:absl:Step 1000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 98.40%, recall = 98.40%, precision = 100.00%, ambient false positives = 13, estimated false positives per hour = 1.34430, loss = 0.00103, auc = 0.99946, average viable recall = 0.951876687
# INFO:absl:Sharding callback duration: 36 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 95.18767%; no faph cutoff is 1.00
# INFO:absl:Step #1500: rate 0.001000, accuracy 99.90%, recall 99.10%, precision 99.60%, cross entropy 0.003208
# INFO:absl:Step 1500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.40%, recall = 99.40%, precision = 100.00%, ambient false positives = 77, estimated false positives per hour = 7.96238, loss = 0.00248, auc = 0.99996, average viable recall = 0.930531256
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 95.18767%; no faph cutoff is 1.00
# INFO:absl:Step #2000: rate 0.001000, accuracy 99.90%, recall 99.18%, precision 99.41%, cross entropy 0.002880
# INFO:absl:Step 2000 (nonstreaming): Validation: recall at no faph = 94.600 with cutoff 0.16, accuracy = 92.00%, recall = 92.00%, precision = 100.00%, ambient false positives = 0, estimated false positives per hour = 0.00000, loss = 0.00257, auc = 0.99200, average viable recall = 0.972709915
# INFO:absl:Sharding callback duration: 46 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.27099%; no faph cutoff is 0.16
# INFO:absl:Step #2500: rate 0.001000, accuracy 99.91%, recall 99.29%, precision 99.52%, cross entropy 0.002876
# INFO:absl:Step 2500 (nonstreaming): Validation: recall at no faph = 91.200 with cutoff 0.21, accuracy = 86.90%, recall = 86.90%, precision = 100.00%, ambient false positives = 0, estimated false positives per hour = 0.00000, loss = 0.00527, auc = 0.98600, average viable recall = 0.969166453
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.27099%; no faph cutoff is 0.16
# INFO:absl:Step #3000: rate 0.001000, accuracy 99.94%, recall 99.58%, precision 99.67%, cross entropy 0.001758
# INFO:absl:Step 3000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.10%, recall = 99.10%, precision = 100.00%, ambient false positives = 5, estimated false positives per hour = 0.51704, loss = 0.00036, auc = 0.99999, average viable recall = 0.941376895
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.27099%; no faph cutoff is 0.16
# INFO:absl:Step #3500: rate 0.001000, accuracy 99.93%, recall 99.48%, precision 99.63%, cross entropy 0.001666
# INFO:absl:Step 3500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 98, estimated false positives per hour = 10.13394, loss = 0.00268, auc = 0.99997, average viable recall = 0.708360316
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.27099%; no faph cutoff is 0.16
# INFO:absl:Step #4000: rate 0.001000, accuracy 99.94%, recall 99.58%, precision 99.66%, cross entropy 0.001629
# INFO:absl:Step 4000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 98.70%, recall = 98.70%, precision = 100.00%, ambient false positives = 7, estimated false positives per hour = 0.72385, loss = 0.00059, auc = 0.99950, average viable recall = 0.961149305
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 97.27099%; no faph cutoff is 0.16
# INFO:absl:Step #4500: rate 0.001000, accuracy 99.95%, recall 99.70%, precision 99.66%, cross entropy 0.001398
# INFO:absl:Step 4500 (nonstreaming): Validation: recall at no faph = 98.100 with cutoff 0.77, accuracy = 99.20%, recall = 99.20%, precision = 100.00%, ambient false positives = 2, estimated false positives per hour = 0.20682, loss = 0.00021, auc = 1.00000, average viable recall = 0.998009404
# INFO:absl:Sharding callback duration: 56 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.80094%; no faph cutoff is 0.77
# INFO:absl:Step #5000: rate 0.001000, accuracy 99.94%, recall 99.54%, precision 99.63%, cross entropy 0.001614
# INFO:absl:Step 5000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 88, estimated false positives per hour = 9.09986, loss = 0.00211, auc = 0.99998, average viable recall = 0.766454093
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.80094%; no faph cutoff is 0.77
# INFO:absl:Step #5500: rate 0.001000, accuracy 99.94%, recall 99.49%, precision 99.68%, cross entropy 0.001659
# INFO:absl:Step 5500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 507, estimated false positives per hour = 52.42762, loss = 0.01389, auc = 0.99977, average viable recall = 0.132472262
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.80094%; no faph cutoff is 0.77
# INFO:absl:Step #6000: rate 0.001000, accuracy 99.96%, recall 99.73%, precision 99.69%, cross entropy 0.001127
# INFO:absl:Step 6000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.20%, recall = 99.20%, precision = 100.00%, ambient false positives = 12, estimated false positives per hour = 1.24089, loss = 0.00036, auc = 1.00000, average viable recall = 0.966408990
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.80094%; no faph cutoff is 0.77
# INFO:absl:Step #6500: rate 0.001000, accuracy 99.97%, recall 99.79%, precision 99.79%, cross entropy 0.000906
# INFO:absl:Step 6500 (nonstreaming): Validation: recall at no faph = 99.900 with cutoff 0.95, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 11, estimated false positives per hour = 1.13748, loss = 0.00021, auc = 1.00000, average viable recall = 0.999974150
# INFO:absl:Sharding callback duration: 36 microseconds
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #7000: rate 0.001000, accuracy 99.94%, recall 99.58%, precision 99.66%, cross entropy 0.001477
# INFO:absl:Step 7000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 28, estimated false positives per hour = 2.89541, loss = 0.00072, auc = 0.99999, average viable recall = 0.916420864
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #7500: rate 0.001000, accuracy 99.98%, recall 99.87%, precision 99.85%, cross entropy 0.000602
# INFO:absl:Step 7500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 19, estimated false positives per hour = 1.96474, loss = 0.00049, auc = 1.00000, average viable recall = 0.974148115
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #8000: rate 0.001000, accuracy 99.97%, recall 99.85%, precision 99.81%, cross entropy 0.000815
# INFO:absl:Step 8000 (nonstreaming): Validation: recall at no faph = 94.100 with cutoff 0.91, accuracy = 96.30%, recall = 96.30%, precision = 100.00%, ambient false positives = 4, estimated false positives per hour = 0.41363, loss = 0.00263, auc = 0.98949, average viable recall = 0.966324559
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #8500: rate 0.001000, accuracy 99.96%, recall 99.72%, precision 99.72%, cross entropy 0.001050
# INFO:absl:Step 8500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 100.00%, recall = 100.00%, precision = 100.00%, ambient false positives = 19, estimated false positives per hour = 1.96474, loss = 0.00053, auc = 0.99999, average viable recall = 0.939454895
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #9000: rate 0.001000, accuracy 99.97%, recall 99.85%, precision 99.81%, cross entropy 0.000877
# INFO:absl:Step 9000 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 99.90%, recall = 99.90%, precision = 100.00%, ambient false positives = 3, estimated false positives per hour = 0.31022, loss = 0.00014, auc = 1.00000, average viable recall = 0.973579376
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #9500: rate 0.001000, accuracy 99.97%, recall 99.74%, precision 99.81%, cross entropy 0.000971
# INFO:absl:Step 9500 (nonstreaming): Validation: recall at no faph = 0.000 with cutoff 1.00, accuracy = 98.10%, recall = 98.10%, precision = 100.00%, ambient false positives = 11, estimated false positives per hour = 1.13748, loss = 0.00082, auc = 0.99849, average viable recall = 0.903782785
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Step #10000: rate 0.001000, accuracy 99.97%, recall 99.76%, precision 99.76%, cross entropy 0.000830
# INFO:absl:Step 10000 (nonstreaming): Validation: recall at no faph = 99.200 with cutoff 0.93, accuracy = 99.70%, recall = 99.70%, precision = 100.00%, ambient false positives = 7, estimated false positives per hour = 0.72385, loss = 0.00018, auc = 1.00000, average viable recall = 0.998086954
# INFO:absl:So far the best minimization quantity is 0.000 with best maximization quantity of 99.99741%; no faph cutoff is 0.95
# INFO:absl:Sharding callback duration: 35 microseconds
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (1, 204, 40)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_1       │ (1, 204, 1, 40)   │          0 │ input_layer_1[0]… │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_6 (Stream)   │ (1, 67, 1, 32)    │      6,400 │ expand_dims_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 67, 1, 32)    │          0 │ stream_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_7 (Stream)   │ (1, 67, 1, 32)    │          0 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (1, 63, 1, 32)    │        192 │ stream_7[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 63, 1, 64)    │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 63, 1, 64)    │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 63, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_8 (Stream)   │ (1, 63, 1, 64)    │          0 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_2     │ [(1, 63, 1, 32),  │          0 │ stream_8[0][0]    │
# │ (ChannelSplit)      │ (1, 63, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_4      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_5      │ (1, 63, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (1, 57, 1, 32)    │        256 │ strided_keep_4[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (1, 53, 1, 32)    │        384 │ strided_keep_5[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_4      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_5      │ (1, 53, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 53, 1, 64)    │          0 │ strided_drop_4[0… │
# │ (Concatenate)       │                   │            │ strided_drop_5[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 53, 1, 64)    │      4,096 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 53, 1, 64)    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 53, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_9 (Stream)   │ (1, 53, 1, 64)    │          0 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_3     │ [(1, 53, 1, 32),  │          0 │ stream_9[0][0]    │
# │ (ChannelSplit)      │ (1, 53, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_6      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_7      │ (1, 53, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (1, 45, 1, 32)    │        320 │ strided_keep_6[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (1, 39, 1, 32)    │        512 │ strided_keep_7[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_6      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_7      │ (1, 39, 1, 32)    │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 39, 1, 64)    │          0 │ strided_drop_6[0… │
# │ (Concatenate)       │                   │            │ strided_drop_7[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 39, 1, 64)    │      4,096 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 39, 1, 64)    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 39, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_10 (Stream)  │ (1, 39, 1, 64)    │          0 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (1, 17, 1, 64)    │      1,536 │ stream_10[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 17, 1, 64)    │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 17, 1, 64)    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 17, 1, 64)    │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_11 (Stream)  │ (1, 17, 1, 64)    │          0 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (1, 1088)         │          0 │ stream_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (1, 1)            │      1,089 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 26,049 (101.75 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 512 (2.00 KB)
# INFO:absl:None
# INFO:absl:Saving streaming model
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 2
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 4
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 10
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 14
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 22
# WARNING:absl:ring_buffer_size_in_time_dim overwritten by the passed-in value: 16
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_audio         │ (1, 3, 40)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expand_dims_2       │ (1, 3, 1, 40)     │          0 │ input_audio[0][0] │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_6 (Stream)   │ (1, 1, 1, 32)     │      6,480 │ expand_dims_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (1, 1, 1, 32)     │          0 │ stream_6[0][0]    │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_7 (Stream)   │ (1, 5, 1, 32)     │        128 │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (1, 1, 1, 32)     │        192 │ stream_7[0][0]    │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (1, 1, 1, 64)     │      2,048 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_8 (Stream)   │ (1, 11, 1, 64)    │        640 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_2     │ [(1, 11, 1, 32),  │          0 │ stream_8[0][0]    │
# │ (ChannelSplit)      │ (1, 11, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_4      │ (1, 7, 1, 32)     │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_5      │ (1, 11, 1, 32)    │          0 │ channel_split_2[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (1, 1, 1, 32)     │        256 │ strided_keep_4[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (1, 1, 1, 32)     │        384 │ strided_keep_5[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_4      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_5      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (1, 1, 1, 64)     │          0 │ strided_drop_4[0… │
# │ (Concatenate)       │                   │            │ strided_drop_5[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (1, 1, 1, 64)     │      4,096 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_9 (Stream)   │ (1, 15, 1, 64)    │        896 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channel_split_3     │ [(1, 15, 1, 32),  │          0 │ stream_9[0][0]    │
# │ (ChannelSplit)      │ (1, 15, 1, 32)]   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_6      │ (1, 9, 1, 32)     │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_keep_7      │ (1, 15, 1, 32)    │          0 │ channel_split_3[… │
# │ (StridedKeep)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_9  │ (1, 1, 1, 32)     │        320 │ strided_keep_6[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_10 │ (1, 1, 1, 32)     │        512 │ strided_keep_7[0… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_6      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ strided_drop_7      │ (1, 1, 1, 32)     │          0 │ depthwise_conv2d… │
# │ (StridedDrop)       │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (1, 1, 1, 64)     │          0 │ strided_drop_6[0… │
# │ (Concatenate)       │                   │            │ strided_drop_7[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (1, 1, 1, 64)     │      4,096 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_10 (Stream)  │ (1, 23, 1, 64)    │      1,408 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_11 │ (1, 1, 1, 64)     │      1,536 │ stream_10[0][0]   │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (1, 1, 1, 64)     │      4,096 │ depthwise_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (1, 1, 1, 64)     │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (1, 1, 1, 64)     │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stream_11 (Stream)  │ (1, 17, 1, 64)    │      1,024 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (1, 1088)         │          0 │ stream_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (1, 1)            │      1,089 │ flatten_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 30,225 (118.07 KB)
#  Trainable params: 25,537 (99.75 KB)
#  Non-trainable params: 4,688 (18.31 KB)
# INFO:absl:Function `call` contains input name(s) resource with unsupported characters which will be renamed to dense_1_1_add_readvariableop_resource in the SavedModel.
# INFO:absl:Function `call` contains input name(s) resource with unsupported characters which will be renamed to dense_1_1_add_readvariableop_resource in the SavedModel.
# INFO:absl:Sharding callback duration: 28 microseconds
# INFO:absl:Sharding callback duration: 26 microseconds
# INFO:absl:Writing fingerprint to trained_models/wakeword/stream_state_internal/fingerprint.pb
# Saved artifact at 'trained_models/wakeword/stream_state_internal'. The following endpoints are available:
#
# * Endpoint 'serve'
#   inputs (POSITIONAL_OR_KEYWORD): TensorSpec(shape=(1, 3, 40), dtype=tf.float32, name=None)
#   training (POSITIONAL_OR_KEYWORD): Literal[None]
#   mask (POSITIONAL_OR_KEYWORD): Literal[None]
# Output Type:
#   TensorSpec(shape=(1, 1), dtype=tf.float32, name=None)
# Captures:
#   40876215808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   5567750816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876217744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876339296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876225136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876212992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876131776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876340704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876224608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876221968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876133712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876217392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876142864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876142160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40876142688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875878960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875880544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875878080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875877904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875881072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875883888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875800736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875797568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875801264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875800912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875797744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875698912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875696448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875696272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875699440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875701200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875695744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875611888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875615232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875696800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875616640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875614176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875617344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875610656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40875622096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   40857847760: TensorSpec(shape=(), dtype=tf.resource, name=None)
# INFO:absl:Converting quantized streaming model to TFLite
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1750315752.087785 11203417 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1750315752.088003 11203417 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-06-19 14:49:12.090826: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: trained_models/wakeword/stream_state_internal
# 2025-06-19 14:49:12.092440: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-06-19 14:49:12.092449: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: trained_models/wakeword/stream_state_internal
# I0000 00:00:1750315752.107009 11203417 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-06-19 14:49:12.109896: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-06-19 14:49:12.206860: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: trained_models/wakeword/stream_state_internal
# 2025-06-19 14:49:12.232479: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 141814 microseconds.
# 2025-06-19 14:49:12.285051: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-06-19 14:49:12.418544: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:4061] Estimated count of arithmetic ops: 0.050 M  ops, equivalently 0.025 M  MACs
# fully_quantize: 0, inference_type: 6, input_inference_type: INT8, output_inference_type: UINT8
# 2025-06-19 14:49:25.920838: I tensorflow/compiler/mlir/lite/flatbuffer_export.cc:4061] Estimated count of arithmetic ops: 0.050 M  ops, equivalently 0.025 M  MACs
# INFO:absl:Testing the TFLite quantized streaming model false accept per hour and false rejection rates at various cutoffs.
# UserWarning:
#         Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#         TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#         See the [migration guide](https://ai.google.dev/edge/litert/migration)
#         for details.
#
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# INFO:absl:Testing the testing_ambient set.
# INFO:absl:Testing the testing set.
# INFO:absl:AUC 0.63677
# INFO:absl:Cutoff 1.00: frr=1.0000; faph=0.000
# INFO:absl:Cutoff 0.99: frr=0.0600; faph=1.125
# INFO:absl:Cutoff 0.98: frr=0.0400; faph=1.687
# INFO:absl:Cutoff 0.97: frr=0.0400; faph=2.000
